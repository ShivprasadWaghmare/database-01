# %%
Q1. What is a database? Differentiate between SQL and NoSQL databases.
ans :  database is collection of structured data  stored electronically  in computer system.

 Parameter                    SQL                                                                    NOSQL  
 
 1.database               1.sql is relationaldatabase            1.NOSQL is non relational or distributed database
                         
 2.schelable              2. vertical schelable                  2.horizontal schelable
                         
3.type                    3.sql database are                     3.document based,key value pair, graph database
                         table based database
                         
 4.use                   4. used for complex                     4.not used for complex query
                           query


2.What is DDL? Explain why CREATE, DROP, ALTER, and TRUNCATE are used with an example.
ans : Data Definition Language (DDL) is a subset of SQL. It is a language for describing data and its relationships in a database. 
   
   It is declarative and can be used to define tables, views, indexes, name spaces, table spaces, databases, stored procedures and functions, triggers and users. Objects can be created using CREATE and deleted using DROP .
   The ALTER command in SQL is used to make changes to a table, view, or the entire database. We can add, modify, and drop constraints, columns, and indexes using the ALTER command in SQL.
   


3.Q3. What is DML? Explain INSERT, UPDATE, and DELETE with an example.
ans: DML: Data Manipulation Language
INSERT: This statement adds table row values. 
UPDATE: This statement updates the values of a column in a table. To use this, the WHERE condition is necessary. 
DELETE: This command removes a particular row from a table.

Q4. What is DQL? Explain SELECT with an example.
ans: Query languages, often known as DQLs or Data Query Languages, are computer languages that are used to make various queries in information systems and databases.
    A SELECT statement retrieves zero or more rows from one or more database tables or database views.
    
5. Explain Primary Key and Foreign Key   
ans:A primary key generally focuses on the uniqueness of the table. It assures the value in the specific column is unique. 
    A foreign key is generally used to build a relationship between the two tables
    
6.  Q6. Write a python code to connect MySQL to python. Explain the cursor() and execute() method.  
ans:      cursor.execute("SELECT * FROM customers")

7.Q7. Give the order of execution of SQL clauses in an SQL query.
ans:  
Order	               Clause	                                           Function
1	                   FROM	                                 Tables are joined to get the base data.
2	                   WHERE	                             The base data is filtered.
3	                   GROUP BY                              The filtered base data is grouped.
4	                   HAVING	                             The grouped base data is filtered.
